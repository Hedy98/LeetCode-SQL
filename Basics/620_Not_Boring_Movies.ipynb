# %% [markdown]
# <a href="https://colab.research.google.com/github/Hedy98/LeetCode-SQL/blob/main/Basics/620_Not_Boring_Movies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **620. Not Boring Movies** (Basic-Easy)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **SOLUTION: MY SQL SERVER**

# %%
SELECT * 
FROM Cinema
WHERE id%2=1 AND description != 'boring'
ORDER BY rating DESC

# %% [markdown]
# **SOLUTION: MY SQL**

# %%
SELECT *
FROM Cinema
WHERE mod(id,2)=1 AND description != 'boring'
ORDER BY rating DESC
