# %% [markdown]
# <a href="https://colab.research.google.com/github/Hedy98/LeetCode-SQL/blob/main/Basics/182_Duplicate_Emails.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **182. Duplicate Emails** (Basic-Easy)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **SOLUTION: MY SQL/ MY SQL SERVER**

# %%
SELECT Email
FROM Person
GROUP BY Email
HAVING COUNT (Email) > 1
