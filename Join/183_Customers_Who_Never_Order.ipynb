# %% [markdown]
# <a href="https://colab.research.google.com/github/Hedy98/LeetCode-SQL/blob/main/Join/183_Customers_Who_Never_Order.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **183. Customers Who Never Order** (Join-Easy)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **SOLUTION: MY SQL SERVER**

# %%
SELECT Nama as Customers
FROM Customers C
LEFT JOIN Orders O
    ON C.Id = O.CustomerId
WHERE O.CustomerId IS NULL
