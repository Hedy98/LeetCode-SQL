# %% [markdown]
# <a href="https://colab.research.google.com/github/Hedy98/LeetCode-SQL/blob/main/SQL%20Command/627_Swap_Salary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **627. Swap Salary** (SQL Command-Easy)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **SOLUTION: MY SQL SERVER**

# %%
UPDATE salary
SET sex = (CASE
            WHEN sex = "f" THEN "m"
            ELSE "f"
          END)
